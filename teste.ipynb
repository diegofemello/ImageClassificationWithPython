# %%
# Importando as bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import glob
import seaborn as sns

# Bibliotecas para o Tensorflow
import tensorflow as tf

from keras.utils import to_categorical
from keras.utils import img_to_array, load_img
from keras import models, layers

# Bibliotecas para o modelo de rede neural convolucional
from keras.applications import MobileNetV3Small
from keras.applications.mobilenet_v3 import preprocess_input


print("Importing libraries completed.")
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Importing libraries completed.
# Num GPUs Available:  1

# %%
# Declarando variáveis

# Caminho dos datasets
path = './chest_xray/'
normal_classe = 'NORMAL'
pneu_classe = 'PNEUMONIA'

# Treino
train_folder = os.path.join(path, 'train/')
train_normal_dir = os.path.join(train_folder, normal_classe)
train_pneu_dir = os.path.join(train_folder, pneu_classe)

# Teste
test_folder = os.path.join(path, 'test/')
test_normal_dir = os.path.join(test_folder, normal_classe)
test_pneu_dir = os.path.join(test_folder, pneu_classe)

# Validação
val_folder = os.path.join(path, 'val/')
val_normal_dir = os.path.join(val_folder, normal_classe)
val_pneu_dir = os.path.join(val_folder, pneu_classe)

# Tamanho das imagens
img_width = 196
img_height = 196

# Variáveis para o treinamento
batch_size = 64
epochs = 10

# %%
# Checando se os nomes das classes são iguais

class_names = os.listdir(train_folder)

if class_names == os.listdir(test_folder) == os.listdir(val_folder):
    print("Class names: %s" % (class_names))
    print("\nDataset class name listing completed.")
else:
    print("\nDataset class name listing failed.")
    raise Exception("Dataset class name listing failed.")
# Out:
# Class names: ['NORMAL', 'PNEUMONIA']
#
# Dataset class name listing completed.

# %%
# Análise dos diretórios de treino, teste e validação
print(train_normal_dir)

# Procurando todas as imagens nos diretórios com extensão jpeg
train_normal_cases = glob.glob(train_normal_dir + '/*jpeg')
train_pneu_cases = glob.glob(train_pneu_dir + '/*jpeg')

test_normal_cases = glob.glob(test_normal_dir + '/*jpeg')
test_pneu_cases = glob.glob(test_pneu_dir + '/*jpeg')

val_normal_cases = glob.glob(val_normal_dir + '/*jpeg')
val_pneu_cases = glob.glob(val_pneu_dir + '/*jpeg')

# Criando listas para os casos de treino, teste e validação
train_list = []
test_list = []
val_list = []

for x in train_normal_cases:
    train_list.append([x, "Normal"])

for x in train_pneu_cases:
    train_list.append([x, "Pneumonia"])

for x in test_normal_cases:
    test_list.append([x, "Normal"])

for x in test_pneu_cases:
    test_list.append([x, "Pneumonia"])

for x in val_normal_cases:
    val_list.append([x, "Normal"])

for x in val_pneu_cases:
    val_list.append([x, "Pneumonia"])

# create dataframes
train_df = pd.DataFrame(train_list, columns=['image', 'Diagnos'])
print(train_df.shape)
test_df = pd.DataFrame(test_list, columns=['image', 'Diagnos'])
print(test_df.shape)
val_df = pd.DataFrame(val_list, columns=['image', 'Diagnos'])
print(val_df.shape)
# Out:
# ./chest_xray/train/NORMAL
# (5216, 2)
# (624, 2)
# (33, 2)

# %%
# plotting the Train, Test and Validation image data

plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
sns.countplot(x=train_df['Diagnos'])
plt.title('Train data')

plt.subplot(1, 3, 2)
sns.countplot(x=test_df['Diagnos'])
plt.title('Test data')

plt.subplot(1, 3, 3)
sns.countplot(x=val_df['Diagnos'])
plt.title('Validation data')

# plt.show()
# Out:
# Text(0.5, 1.0, 'Validation data')

# %%
# Plotting raw images just for review

plt.figure(figsize=(20, 8))
for i, img_path in enumerate(train_df[train_df['Diagnos'] == "Pneumonia"][0:4]['image']):
    plt.subplot(2, 4, i+1)
    plt.axis('off')
    img = plt.imread(img_path)
    plt.imshow(img, cmap='gray')
    plt.title('Pneumonia')

for i, img_path in enumerate(train_df[train_df['Diagnos'] == "Normal"][0:4]['image']):
    plt.subplot(2, 4, 4+i+1)
    plt.axis('off')
    img = plt.imread(img_path)
    plt.imshow(img, cmap='gray')
    plt.title('Normal')

# %%
def gray_to_rgb(img):
    x = np.dot(img[..., :3], [0.2989, 0.5870, 0.1140])
    mychannel = np.repeat(x[:, :, np.newaxis], 3, axis=2)
    return mychannel


def prepare_image(image_path):
    img = load_img(image_path, target_size=(img_width, img_height))

    # Converting to arrary
    img = img_to_array(img)

    # Converting to RGB to match the MobileNetV3Small model
    img = gray_to_rgb(img)

    # Transfer Learning: this is to apply preprocess of MobileNetV3Small model to our images before passing it to MobileNetV3Small
    img = preprocess_input(img)  # Optional step

    return img

# %%
# Preparing Training image data (image array and class name) for processing

# Declaring variables
x = []  # to store array value of the images
y = []  # to store the labels of the images

for folder in os.listdir(train_folder):
    image_list = os.listdir(os.path.join(train_folder, folder))
    print("Preparing Training Dataset for %s with total length %d" %
          (folder, len(image_list)))

    for img_name in image_list:
        # Loading images
        image_path = os.path.join(train_folder, folder, img_name)

        # Prepare image
        img = prepare_image(image_path)

        # Appending the arrarys
        x.append(img)  # appending image array
        # appending class index to the array
        y.append(class_names.index(folder))


print("Preparing Training Dataset Completed.")
# Out:
# Preparing Training Dataset for NORMAL with total length 1341
# Preparing Training Dataset for PNEUMONIA with total length 3875
# Preparing Training Dataset Completed.

# %%
# Preparing validation images data (image array and class name) for processing

# Declaring variables
val_images = []
val_images_Original = []
val_image_label = []  # to store the labels of the images

for folder in os.listdir(val_folder):
    image_list = os.listdir(val_folder+"/"+folder)
    print("Preparing Training Dataset for %s with total length %d" %
          (folder, len(image_list)))

    for img_name in image_list:
        image_path = os.path.join(val_folder, folder, img_name)

        # Prepare image
        img = prepare_image(image_path)

        val_images_Original.append(img.copy())

        # Appending arrays
        val_images.append(img)  # appending image array
        val_image_label.append(class_names.index(folder))

print("Preparing Validation Dataset Completed.")
# Out:
# Preparing Training Dataset for NORMAL with total length 16
# Preparing Training Dataset for PNEUMONIA with total length 17
# Preparing Validation Dataset Completed.

# %%
# Preparing validation images data (image array and class name) for processing

# Declaring variables
test_images = []
test_images_Original = []
test_image_label = []  # to store the labels of the images

for folder in os.listdir(test_folder):
    image_list = os.listdir(test_folder+"/"+folder)
    print("Preparing Training Dataset for %s with total length %d" %
          (folder, len(image_list)))
    for img_name in image_list:
        image_path = os.path.join(test_folder, folder, img_name)

        # Prepare image
        img = prepare_image(image_path)

        # Saving original images, will be used just for display at the end
        test_images_Original.append(img.copy())

        # Transfer Learning: this is to apply preprocess of MobileNetV3Small to our images before passing it to MobileNetV3Small
        img = preprocess_input(img)  # Optional step

        # Appending arrays
        test_images.append(img)  # appending image array
        test_image_label.append(class_names.index(folder))

print("Preparing Test Dataset Completed.")
# Out:
# Preparing Training Dataset for NORMAL with total length 234
# Preparing Training Dataset for PNEUMONIA with total length 390
# Preparing Test Dataset Completed.

# %%
# Verifying the output

# Training Dataset
print("Training Dataset")

x = np.array(x)  # Converting to np arrary to pass to the model
print(x.shape)

y = to_categorical(y)  # onehot encoding of the labels
# print(y)
print(y.shape)

# ===========

# Test Dataset
print("Test Dataset")

test_images = np.array(test_images)
print(test_images.shape)

# onehot encoding of the labels)
test_image_label = to_categorical(test_image_label)
print(test_image_label.shape)

# ===========

# Validation Dataset
print("Validation Dataset")

val_images = np.array(val_images)
print(val_images.shape)

# onehot encoding of the labels)
val_image_label = to_categorical(val_image_label)
print(val_image_label.shape)
# Out:
# Training Dataset
# (5216, 196, 196, 3)
# (5216, 2)
# Test Dataset
# (624, 196, 196, 3)
# (624, 2)
# Validation Dataset
# (33, 196, 196, 3)
# (33, 2)

# %%
# Modelling WITH Transfer Learning

# Here we will prepare model as per our requirements

print("Summary of Custom MobileNetV3Small model.\n")
print("1) We setup input layer and 2) We removed top (last) layer. \n")

# let us prepare our input_layer to pass our image size. default is (224,224,3). we will change it to (224,224,3)
input_layer = layers.Input(shape=(img_width, img_height, 3))

# initialize the transfer model MobileNetV3Small with appropriate properties per our need.
# we are passing paramers as following
# 1) weights='imagenet' - Using this we are carring weights as of original weights.
# 2) input_tensor to pass the MobileNetV3Small using input_tensor
# 3) we want to change the last layer so we are not including top layer
model_vgg16 = MobileNetV3Small(
    weights='imagenet', input_tensor=input_layer, include_top=False)

# See the summary of the model with our properties.
model_vgg16.summary()
# Out:
# Summary of Custom MobileNetV3Small model.
#
# 1) We setup input layer and 2) We removed top (last) layer.
#
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 196, 196, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 196, 196, 3)  0           ['input_2[0][0]']
#
#  Conv (Conv2D)                  (None, 98, 98, 16)   432         ['rescaling_1[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 98, 98, 16)  64          ['Conv[0][0]']
#  tion)
#
#  tf.__operators__.add_27 (TFOpL  (None, 98, 98, 16)  0           ['Conv/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_32 (ReLU)                (None, 98, 98, 16)   0           ['tf.__operators__.add_27[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 98, 98, 16)  0           ['re_lu_32[0][0]']
#  a)
#
#  multiply_18 (Multiply)         (None, 98, 98, 16)   0           ['Conv/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_27[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, 99, 99, 16)  0           ['multiply_18[0][0]']
#  eroPadding2D)
#
#  expanded_conv/depthwise (Depth  (None, 49, 49, 16)  144         ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                                                     0]']
#
#  expanded_conv/depthwise/BatchN  (None, 49, 49, 16)  64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_33 (ReLU)                (None, 49, 49, 16)   0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_33[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_28 (TFOpL  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  ambda)                                                          nv_1[0][0]']
#
#  re_lu_34 (ReLU)                (None, 1, 1, 16)     0           ['tf.__operators__.add_28[0][0]']
#
#  tf.math.multiply_28 (TFOpLambd  (None, 1, 1, 16)    0           ['re_lu_34[0][0]']
#  a)
#
#  expanded_conv/squeeze_excite/M  (None, 49, 49, 16)  0           ['re_lu_33[0][0]',
#  ul (Multiply)                                                    'tf.math.multiply_28[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 49, 49, 16)  256         ['expanded_conv/squeeze_excite/Mu
#                                                                  l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 49, 49, 16)  64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv_1/expand (Conv2D  (None, 49, 49, 72)  1152        ['expanded_conv/project/BatchNorm
#  )                                                               [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, 49, 49, 72)  288         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_35 (ReLU)                (None, 49, 49, 72)   0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 51, 51, 72)  0           ['re_lu_35[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 25, 25, 72)  648         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 25, 25, 72)  288         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_36 (ReLU)                (None, 25, 25, 72)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 25, 25, 24)  1728        ['re_lu_36[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 25, 25, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 25, 25, 88)  2112        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 25, 25, 88)  352         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_37 (ReLU)                (None, 25, 25, 88)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 25, 25, 88)  792         ['re_lu_37[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 25, 25, 88)  352         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_38 (ReLU)                (None, 25, 25, 88)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 25, 25, 24)  2112        ['re_lu_38[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 25, 25, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 25, 25, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 25, 25, 96)  2304        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 25, 25, 96)  384         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_29 (TFOpL  (None, 25, 25, 96)  0           ['expanded_conv_3/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_39 (ReLU)                (None, 25, 25, 96)   0           ['tf.__operators__.add_29[0][0]']
#
#  tf.math.multiply_29 (TFOpLambd  (None, 25, 25, 96)  0           ['re_lu_39[0][0]']
#  a)
#
#  multiply_19 (Multiply)         (None, 25, 25, 96)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_29[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 29, 29, 96)  0           ['multiply_19[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 13, 13, 96)  2400        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 13, 13, 96)  384         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_30 (TFOpL  (None, 13, 13, 96)  0           ['expanded_conv_3/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_40 (ReLU)                (None, 13, 13, 96)   0           ['tf.__operators__.add_30[0][0]']
#
#  tf.math.multiply_30 (TFOpLambd  (None, 13, 13, 96)  0           ['re_lu_40[0][0]']
#  a)
#
#  multiply_20 (Multiply)         (None, 13, 13, 96)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_30[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_20[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_31 (TFOpL  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_41 (ReLU)                (None, 1, 1, 96)     0           ['tf.__operators__.add_31[0][0]']
#
#  tf.math.multiply_31 (TFOpLambd  (None, 1, 1, 96)    0           ['re_lu_41[0][0]']
#  a)
#
#  expanded_conv_3/squeeze_excite  (None, 13, 13, 96)  0           ['multiply_20[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_31[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 13, 13, 40)  3840        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 13, 13, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 13, 13, 240)  9600       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 13, 13, 240)  960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_32 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_4/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_42 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_32[0][0]']
#
#  tf.math.multiply_32 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_42[0][0]']
#  a)
#
#  multiply_21 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_32[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 13, 13, 240)  6000       ['multiply_21[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 13, 13, 240)  960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_33 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_4/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_43 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_33[0][0]']
#
#  tf.math.multiply_33 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_43[0][0]']
#  a)
#
#  multiply_22 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_33[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_22[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_34 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_44 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_34[0][0]']
#
#  tf.math.multiply_34 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_44[0][0]']
#  a)
#
#  expanded_conv_4/squeeze_excite  (None, 13, 13, 240)  0          ['multiply_22[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_34[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 13, 13, 40)  9600        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 13, 13, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 13, 13, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 13, 13, 240)  9600       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 13, 13, 240)  960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_35 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_5/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_45 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_35[0][0]']
#
#  tf.math.multiply_35 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_45[0][0]']
#  a)
#
#  multiply_23 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_35[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 13, 13, 240)  6000       ['multiply_23[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 13, 13, 240)  960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_36 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_5/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_46 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_36[0][0]']
#
#  tf.math.multiply_36 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_46[0][0]']
#  a)
#
#  multiply_24 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_36[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_24[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_37 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_47 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_37[0][0]']
#
#  tf.math.multiply_37 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_47[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, 13, 13, 240)  0          ['multiply_24[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_37[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 13, 13, 40)  9600        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 13, 13, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 13, 13, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 13, 13, 120)  4800       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 13, 13, 120)  480        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_38 (TFOpL  (None, 13, 13, 120)  0          ['expanded_conv_6/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_48 (ReLU)                (None, 13, 13, 120)  0           ['tf.__operators__.add_38[0][0]']
#
#  tf.math.multiply_38 (TFOpLambd  (None, 13, 13, 120)  0          ['re_lu_48[0][0]']
#  a)
#
#  multiply_25 (Multiply)         (None, 13, 13, 120)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_38[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, 13, 13, 120)  3000       ['multiply_25[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_6/depthwise/Batc  (None, 13, 13, 120)  480        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_39 (TFOpL  (None, 13, 13, 120)  0          ['expanded_conv_6/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_49 (ReLU)                (None, 13, 13, 120)  0           ['tf.__operators__.add_39[0][0]']
#
#  tf.math.multiply_39 (TFOpLambd  (None, 13, 13, 120)  0          ['re_lu_49[0][0]']
#  a)
#
#  multiply_26 (Multiply)         (None, 13, 13, 120)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_39[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   0           ['multiply_26[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_6/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_6/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_6/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_40 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_6/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_50 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_40[0][0]']
#
#  tf.math.multiply_40 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_50[0][0]']
#  a)
#
#  expanded_conv_6/squeeze_excite  (None, 13, 13, 120)  0          ['multiply_26[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_40[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 13, 13, 48)  5760        ['expanded_conv_6/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_6/project/BatchN  (None, 13, 13, 48)  192         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 13, 13, 144)  6912       ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 13, 13, 144)  576        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_41 (TFOpL  (None, 13, 13, 144)  0          ['expanded_conv_7/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_51 (ReLU)                (None, 13, 13, 144)  0           ['tf.__operators__.add_41[0][0]']
#
#  tf.math.multiply_41 (TFOpLambd  (None, 13, 13, 144)  0          ['re_lu_51[0][0]']
#  a)
#
#  multiply_27 (Multiply)         (None, 13, 13, 144)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_41[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 13, 13, 144)  3600       ['multiply_27[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 13, 13, 144)  576        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_42 (TFOpL  (None, 13, 13, 144)  0          ['expanded_conv_7/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_52 (ReLU)                (None, 13, 13, 144)  0           ['tf.__operators__.add_42[0][0]']
#
#  tf.math.multiply_42 (TFOpLambd  (None, 13, 13, 144)  0          ['re_lu_52[0][0]']
#  a)
#
#  multiply_28 (Multiply)         (None, 13, 13, 144)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_42[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   0           ['multiply_28[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    5800        ['expanded_conv_7/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    0           ['expanded_conv_7/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   5904        ['expanded_conv_7/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_43 (TFOpL  (None, 1, 1, 144)   0           ['expanded_conv_7/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_53 (ReLU)                (None, 1, 1, 144)    0           ['tf.__operators__.add_43[0][0]']
#
#  tf.math.multiply_43 (TFOpLambd  (None, 1, 1, 144)   0           ['re_lu_53[0][0]']
#  a)
#
#  expanded_conv_7/squeeze_excite  (None, 13, 13, 144)  0          ['multiply_28[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_43[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 13, 13, 48)  6912        ['expanded_conv_7/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_7/project/BatchN  (None, 13, 13, 48)  192         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 13, 13, 48)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 13, 13, 288)  13824      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 13, 13, 288)  1152       ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_44 (TFOpL  (None, 13, 13, 288)  0          ['expanded_conv_8/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_54 (ReLU)                (None, 13, 13, 288)  0           ['tf.__operators__.add_44[0][0]']
#
#  tf.math.multiply_44 (TFOpLambd  (None, 13, 13, 288)  0          ['re_lu_54[0][0]']
#  a)
# ...
#
#  expanded_conv_9/expand (Conv2D  (None, 7, 7, 576)   55296       ['expanded_conv_8/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_9/expand/BatchNo  (None, 7, 7, 576)   2304        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_47 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_57 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_47[0][0]']
#
#  tf.math.multiply_47 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_57[0][0]']
#  a)
#
#  multiply_31 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_47[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 7, 7, 576)   14400       ['multiply_31[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 7, 7, 576)   2304        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_48 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_58 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_48[0][0]']
#
#  tf.math.multiply_48 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_58[0][0]']
#  a)
#
#  multiply_32 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_48[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   0           ['multiply_32[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   83088       ['expanded_conv_9/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   0           ['expanded_conv_9/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   83520       ['expanded_conv_9/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_49 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_9/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_59 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_49[0][0]']
#
#  tf.math.multiply_49 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_59[0][0]']
#  a)
#
#  expanded_conv_9/squeeze_excite  (None, 7, 7, 576)   0           ['multiply_32[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_49[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 7, 7, 96)    55296       ['expanded_conv_9/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_9/project/BatchN  (None, 7, 7, 96)    384         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 7, 7, 96)     0           ['expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 7, 7, 576)   55296       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 7, 7, 576)   2304        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_50 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_60 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_50[0][0]']
#
#  tf.math.multiply_50 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_60[0][0]']
#  a)
#
#  multiply_33 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_50[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 7, 7, 576)   14400       ['multiply_33[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 7, 7, 576)   2304        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_51 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_61 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_51[0][0]']
#
#  tf.math.multiply_51 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_61[0][0]']
#  a)
#
#  multiply_34 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_51[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   0           ['multiply_34[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   83088       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   83520       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_52 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_10/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_62 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_52[0][0]']
#
#  tf.math.multiply_52 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_62[0][0]']
#  a)
#
#  expanded_conv_10/squeeze_excit  (None, 7, 7, 576)   0           ['multiply_34[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_52[0][0]']
#
#  expanded_conv_10/project (Conv  (None, 7, 7, 96)    55296       ['expanded_conv_10/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_10/project/Batch  (None, 7, 7, 96)    384         ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_10/Add (Add)     (None, 7, 7, 96)     0           ['expanded_conv_9/Add[0][0]',
#                                                                   'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 7, 7, 576)    55296       ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 7, 7, 576)   2304        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_53 (TFOpL  (None, 7, 7, 576)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_63 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_53[0][0]']
#
#  tf.math.multiply_53 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_63[0][0]']
#  a)
#
#  multiply_35 (Multiply)         (None, 7, 7, 576)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_53[0][0]']
#
# ==================================================================================================
# Total params: 939,120
# Trainable params: 927,008
# Non-trainable params: 12,112
# __________________________________________________________________________________________________

# %%
# access the current last layer of the model and add flatten and dense after it

print("Summary of Custom MobileNetV3Small model.\n")
print("1) We flatten the last layer and added 1 Dense layer and 1 output layer.\n")

last_layer = model_vgg16.output  # we are taking last layer of the model

# Add flatten layer: we are extending Neural Network by adding flattn layer
flatten = layers.Flatten()(last_layer)

# Add dense layer
# dense1=layers.Dense(100,activation='relu')(flatten)

# Add dense layer to the final output layer
output_layer = layers.Dense(2, activation='softmax')(flatten)

# Creating modle with input and output layer
model = models.Model(inputs=input_layer, outputs=output_layer)

# Summarize the model
model.summary()
# Out:
# Summary of Custom MobileNetV3Small model.
#
# 1) We flatten the last layer and added 1 Dense layer and 1 output layer.
#
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 196, 196, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 196, 196, 3)  0           ['input_2[0][0]']
#
#  Conv (Conv2D)                  (None, 98, 98, 16)   432         ['rescaling_1[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 98, 98, 16)  64          ['Conv[0][0]']
#  tion)
#
#  tf.__operators__.add_27 (TFOpL  (None, 98, 98, 16)  0           ['Conv/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_32 (ReLU)                (None, 98, 98, 16)   0           ['tf.__operators__.add_27[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 98, 98, 16)  0           ['re_lu_32[0][0]']
#  a)
#
#  multiply_18 (Multiply)         (None, 98, 98, 16)   0           ['Conv/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_27[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, 99, 99, 16)  0           ['multiply_18[0][0]']
#  eroPadding2D)
#
#  expanded_conv/depthwise (Depth  (None, 49, 49, 16)  144         ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                                                     0]']
#
#  expanded_conv/depthwise/BatchN  (None, 49, 49, 16)  64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_33 (ReLU)                (None, 49, 49, 16)   0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_33[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_28 (TFOpL  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  ambda)                                                          nv_1[0][0]']
#
#  re_lu_34 (ReLU)                (None, 1, 1, 16)     0           ['tf.__operators__.add_28[0][0]']
#
#  tf.math.multiply_28 (TFOpLambd  (None, 1, 1, 16)    0           ['re_lu_34[0][0]']
#  a)
#
#  expanded_conv/squeeze_excite/M  (None, 49, 49, 16)  0           ['re_lu_33[0][0]',
#  ul (Multiply)                                                    'tf.math.multiply_28[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 49, 49, 16)  256         ['expanded_conv/squeeze_excite/Mu
#                                                                  l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 49, 49, 16)  64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv_1/expand (Conv2D  (None, 49, 49, 72)  1152        ['expanded_conv/project/BatchNorm
#  )                                                               [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, 49, 49, 72)  288         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_35 (ReLU)                (None, 49, 49, 72)   0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 51, 51, 72)  0           ['re_lu_35[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 25, 25, 72)  648         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 25, 25, 72)  288         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_36 (ReLU)                (None, 25, 25, 72)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 25, 25, 24)  1728        ['re_lu_36[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 25, 25, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 25, 25, 88)  2112        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 25, 25, 88)  352         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_37 (ReLU)                (None, 25, 25, 88)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 25, 25, 88)  792         ['re_lu_37[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 25, 25, 88)  352         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_38 (ReLU)                (None, 25, 25, 88)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 25, 25, 24)  2112        ['re_lu_38[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 25, 25, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 25, 25, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 25, 25, 96)  2304        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 25, 25, 96)  384         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_29 (TFOpL  (None, 25, 25, 96)  0           ['expanded_conv_3/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_39 (ReLU)                (None, 25, 25, 96)   0           ['tf.__operators__.add_29[0][0]']
#
#  tf.math.multiply_29 (TFOpLambd  (None, 25, 25, 96)  0           ['re_lu_39[0][0]']
#  a)
#
#  multiply_19 (Multiply)         (None, 25, 25, 96)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_29[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 29, 29, 96)  0           ['multiply_19[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 13, 13, 96)  2400        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 13, 13, 96)  384         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_30 (TFOpL  (None, 13, 13, 96)  0           ['expanded_conv_3/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_40 (ReLU)                (None, 13, 13, 96)   0           ['tf.__operators__.add_30[0][0]']
#
#  tf.math.multiply_30 (TFOpLambd  (None, 13, 13, 96)  0           ['re_lu_40[0][0]']
#  a)
#
#  multiply_20 (Multiply)         (None, 13, 13, 96)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_30[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_20[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_31 (TFOpL  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_41 (ReLU)                (None, 1, 1, 96)     0           ['tf.__operators__.add_31[0][0]']
#
#  tf.math.multiply_31 (TFOpLambd  (None, 1, 1, 96)    0           ['re_lu_41[0][0]']
#  a)
#
#  expanded_conv_3/squeeze_excite  (None, 13, 13, 96)  0           ['multiply_20[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_31[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 13, 13, 40)  3840        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 13, 13, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 13, 13, 240)  9600       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 13, 13, 240)  960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_32 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_4/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_42 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_32[0][0]']
#
#  tf.math.multiply_32 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_42[0][0]']
#  a)
#
#  multiply_21 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_32[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 13, 13, 240)  6000       ['multiply_21[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 13, 13, 240)  960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_33 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_4/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_43 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_33[0][0]']
#
#  tf.math.multiply_33 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_43[0][0]']
#  a)
#
#  multiply_22 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_33[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_22[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_34 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_44 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_34[0][0]']
#
#  tf.math.multiply_34 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_44[0][0]']
#  a)
#
#  expanded_conv_4/squeeze_excite  (None, 13, 13, 240)  0          ['multiply_22[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_34[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 13, 13, 40)  9600        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 13, 13, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 13, 13, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 13, 13, 240)  9600       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 13, 13, 240)  960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_35 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_5/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_45 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_35[0][0]']
#
#  tf.math.multiply_35 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_45[0][0]']
#  a)
#
#  multiply_23 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_35[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 13, 13, 240)  6000       ['multiply_23[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 13, 13, 240)  960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_36 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_5/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_46 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_36[0][0]']
#
#  tf.math.multiply_36 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_46[0][0]']
#  a)
#
#  multiply_24 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_36[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_24[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_37 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_47 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_37[0][0]']
#
#  tf.math.multiply_37 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_47[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, 13, 13, 240)  0          ['multiply_24[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_37[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 13, 13, 40)  9600        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 13, 13, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 13, 13, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 13, 13, 120)  4800       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 13, 13, 120)  480        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_38 (TFOpL  (None, 13, 13, 120)  0          ['expanded_conv_6/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_48 (ReLU)                (None, 13, 13, 120)  0           ['tf.__operators__.add_38[0][0]']
#
#  tf.math.multiply_38 (TFOpLambd  (None, 13, 13, 120)  0          ['re_lu_48[0][0]']
#  a)
#
#  multiply_25 (Multiply)         (None, 13, 13, 120)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_38[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, 13, 13, 120)  3000       ['multiply_25[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_6/depthwise/Batc  (None, 13, 13, 120)  480        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_39 (TFOpL  (None, 13, 13, 120)  0          ['expanded_conv_6/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_49 (ReLU)                (None, 13, 13, 120)  0           ['tf.__operators__.add_39[0][0]']
#
#  tf.math.multiply_39 (TFOpLambd  (None, 13, 13, 120)  0          ['re_lu_49[0][0]']
#  a)
#
#  multiply_26 (Multiply)         (None, 13, 13, 120)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_39[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   0           ['multiply_26[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_6/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_6/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_6/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_40 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_6/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_50 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_40[0][0]']
#
#  tf.math.multiply_40 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_50[0][0]']
#  a)
#
#  expanded_conv_6/squeeze_excite  (None, 13, 13, 120)  0          ['multiply_26[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_40[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 13, 13, 48)  5760        ['expanded_conv_6/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_6/project/BatchN  (None, 13, 13, 48)  192         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 13, 13, 144)  6912       ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 13, 13, 144)  576        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_41 (TFOpL  (None, 13, 13, 144)  0          ['expanded_conv_7/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_51 (ReLU)                (None, 13, 13, 144)  0           ['tf.__operators__.add_41[0][0]']
#
#  tf.math.multiply_41 (TFOpLambd  (None, 13, 13, 144)  0          ['re_lu_51[0][0]']
#  a)
#
#  multiply_27 (Multiply)         (None, 13, 13, 144)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_41[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 13, 13, 144)  3600       ['multiply_27[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 13, 13, 144)  576        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_42 (TFOpL  (None, 13, 13, 144)  0          ['expanded_conv_7/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_52 (ReLU)                (None, 13, 13, 144)  0           ['tf.__operators__.add_42[0][0]']
#
#  tf.math.multiply_42 (TFOpLambd  (None, 13, 13, 144)  0          ['re_lu_52[0][0]']
#  a)
#
#  multiply_28 (Multiply)         (None, 13, 13, 144)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_42[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   0           ['multiply_28[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    5800        ['expanded_conv_7/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    0           ['expanded_conv_7/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   5904        ['expanded_conv_7/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_43 (TFOpL  (None, 1, 1, 144)   0           ['expanded_conv_7/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_53 (ReLU)                (None, 1, 1, 144)    0           ['tf.__operators__.add_43[0][0]']
#
#  tf.math.multiply_43 (TFOpLambd  (None, 1, 1, 144)   0           ['re_lu_53[0][0]']
#  a)
#
#  expanded_conv_7/squeeze_excite  (None, 13, 13, 144)  0          ['multiply_28[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_43[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 13, 13, 48)  6912        ['expanded_conv_7/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_7/project/BatchN  (None, 13, 13, 48)  192         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 13, 13, 48)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 13, 13, 288)  13824      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 13, 13, 288)  1152       ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_44 (TFOpL  (None, 13, 13, 288)  0          ['expanded_conv_8/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_54 (ReLU)                (None, 13, 13, 288)  0           ['tf.__operators__.add_44[0][0]']
#
#  tf.math.multiply_44 (TFOpLambd  (None, 13, 13, 288)  0          ['re_lu_54[0][0]']
#  a)
#
# ...
#  expanded_conv_9/expand/BatchNo  (None, 7, 7, 576)   2304        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_47 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_57 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_47[0][0]']
#
#  tf.math.multiply_47 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_57[0][0]']
#  a)
#
#  multiply_31 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_47[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 7, 7, 576)   14400       ['multiply_31[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 7, 7, 576)   2304        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_48 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_58 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_48[0][0]']
#
#  tf.math.multiply_48 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_58[0][0]']
#  a)
#
#  multiply_32 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_48[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   0           ['multiply_32[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   83088       ['expanded_conv_9/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   0           ['expanded_conv_9/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   83520       ['expanded_conv_9/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_49 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_9/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_59 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_49[0][0]']
#
#  tf.math.multiply_49 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_59[0][0]']
#  a)
#
#  expanded_conv_9/squeeze_excite  (None, 7, 7, 576)   0           ['multiply_32[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_49[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 7, 7, 96)    55296       ['expanded_conv_9/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_9/project/BatchN  (None, 7, 7, 96)    384         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 7, 7, 96)     0           ['expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 7, 7, 576)   55296       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 7, 7, 576)   2304        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_50 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_60 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_50[0][0]']
#
#  tf.math.multiply_50 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_60[0][0]']
#  a)
#
#  multiply_33 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_50[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 7, 7, 576)   14400       ['multiply_33[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 7, 7, 576)   2304        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_51 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_61 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_51[0][0]']
#
#  tf.math.multiply_51 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_61[0][0]']
#  a)
#
#  multiply_34 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_51[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   0           ['multiply_34[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   83088       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   83520       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_52 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_10/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_62 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_52[0][0]']
#
#  tf.math.multiply_52 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_62[0][0]']
#  a)
#
#  expanded_conv_10/squeeze_excit  (None, 7, 7, 576)   0           ['multiply_34[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_52[0][0]']
#
#  expanded_conv_10/project (Conv  (None, 7, 7, 96)    55296       ['expanded_conv_10/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_10/project/Batch  (None, 7, 7, 96)    384         ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_10/Add (Add)     (None, 7, 7, 96)     0           ['expanded_conv_9/Add[0][0]',
#                                                                   'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 7, 7, 576)    55296       ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 7, 7, 576)   2304        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_53 (TFOpL  (None, 7, 7, 576)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_63 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_53[0][0]']
#
#  tf.math.multiply_53 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_63[0][0]']
#  a)
#
#  multiply_35 (Multiply)         (None, 7, 7, 576)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_53[0][0]']
#
#  flatten_1 (Flatten)            (None, 28224)        0           ['multiply_35[0][0]']
#
#  dense_1 (Dense)                (None, 2)            56450       ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 995,570
# Trainable params: 983,458
# Non-trainable params: 12,112
# __________________________________________________________________________________________________

# %%
# we will freez all the layers except the last layer

# we are making all the layers intrainable except the last layer
print("We are making all the layers intrainable except the last layer. \n")
for layer in model.layers[:-1]:
    layer.trainable = False
model.summary()
# Out:
# We are making all the layers intrainable except the last layer.
#
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 196, 196, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 196, 196, 3)  0           ['input_2[0][0]']
#
#  Conv (Conv2D)                  (None, 98, 98, 16)   432         ['rescaling_1[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 98, 98, 16)  64          ['Conv[0][0]']
#  tion)
#
#  tf.__operators__.add_27 (TFOpL  (None, 98, 98, 16)  0           ['Conv/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_32 (ReLU)                (None, 98, 98, 16)   0           ['tf.__operators__.add_27[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 98, 98, 16)  0           ['re_lu_32[0][0]']
#  a)
#
#  multiply_18 (Multiply)         (None, 98, 98, 16)   0           ['Conv/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_27[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, 99, 99, 16)  0           ['multiply_18[0][0]']
#  eroPadding2D)
#
#  expanded_conv/depthwise (Depth  (None, 49, 49, 16)  144         ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                                                     0]']
#
#  expanded_conv/depthwise/BatchN  (None, 49, 49, 16)  64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_33 (ReLU)                (None, 49, 49, 16)   0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_33[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_28 (TFOpL  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  ambda)                                                          nv_1[0][0]']
#
#  re_lu_34 (ReLU)                (None, 1, 1, 16)     0           ['tf.__operators__.add_28[0][0]']
#
#  tf.math.multiply_28 (TFOpLambd  (None, 1, 1, 16)    0           ['re_lu_34[0][0]']
#  a)
#
#  expanded_conv/squeeze_excite/M  (None, 49, 49, 16)  0           ['re_lu_33[0][0]',
#  ul (Multiply)                                                    'tf.math.multiply_28[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 49, 49, 16)  256         ['expanded_conv/squeeze_excite/Mu
#                                                                  l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 49, 49, 16)  64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv_1/expand (Conv2D  (None, 49, 49, 72)  1152        ['expanded_conv/project/BatchNorm
#  )                                                               [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, 49, 49, 72)  288         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_35 (ReLU)                (None, 49, 49, 72)   0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 51, 51, 72)  0           ['re_lu_35[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 25, 25, 72)  648         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 25, 25, 72)  288         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_36 (ReLU)                (None, 25, 25, 72)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 25, 25, 24)  1728        ['re_lu_36[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 25, 25, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 25, 25, 88)  2112        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 25, 25, 88)  352         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_37 (ReLU)                (None, 25, 25, 88)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 25, 25, 88)  792         ['re_lu_37[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 25, 25, 88)  352         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_38 (ReLU)                (None, 25, 25, 88)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 25, 25, 24)  2112        ['re_lu_38[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 25, 25, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 25, 25, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 25, 25, 96)  2304        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 25, 25, 96)  384         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_29 (TFOpL  (None, 25, 25, 96)  0           ['expanded_conv_3/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_39 (ReLU)                (None, 25, 25, 96)   0           ['tf.__operators__.add_29[0][0]']
#
#  tf.math.multiply_29 (TFOpLambd  (None, 25, 25, 96)  0           ['re_lu_39[0][0]']
#  a)
#
#  multiply_19 (Multiply)         (None, 25, 25, 96)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_29[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 29, 29, 96)  0           ['multiply_19[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 13, 13, 96)  2400        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 13, 13, 96)  384         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_30 (TFOpL  (None, 13, 13, 96)  0           ['expanded_conv_3/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_40 (ReLU)                (None, 13, 13, 96)   0           ['tf.__operators__.add_30[0][0]']
#
#  tf.math.multiply_30 (TFOpLambd  (None, 13, 13, 96)  0           ['re_lu_40[0][0]']
#  a)
#
#  multiply_20 (Multiply)         (None, 13, 13, 96)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_30[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_20[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_31 (TFOpL  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_41 (ReLU)                (None, 1, 1, 96)     0           ['tf.__operators__.add_31[0][0]']
#
#  tf.math.multiply_31 (TFOpLambd  (None, 1, 1, 96)    0           ['re_lu_41[0][0]']
#  a)
#
#  expanded_conv_3/squeeze_excite  (None, 13, 13, 96)  0           ['multiply_20[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_31[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 13, 13, 40)  3840        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 13, 13, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 13, 13, 240)  9600       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 13, 13, 240)  960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_32 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_4/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_42 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_32[0][0]']
#
#  tf.math.multiply_32 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_42[0][0]']
#  a)
#
#  multiply_21 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_32[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 13, 13, 240)  6000       ['multiply_21[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 13, 13, 240)  960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_33 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_4/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_43 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_33[0][0]']
#
#  tf.math.multiply_33 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_43[0][0]']
#  a)
#
#  multiply_22 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_33[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_22[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_34 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_44 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_34[0][0]']
#
#  tf.math.multiply_34 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_44[0][0]']
#  a)
#
#  expanded_conv_4/squeeze_excite  (None, 13, 13, 240)  0          ['multiply_22[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_34[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 13, 13, 40)  9600        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 13, 13, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 13, 13, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 13, 13, 240)  9600       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 13, 13, 240)  960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_35 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_5/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_45 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_35[0][0]']
#
#  tf.math.multiply_35 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_45[0][0]']
#  a)
#
#  multiply_23 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_35[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 13, 13, 240)  6000       ['multiply_23[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 13, 13, 240)  960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_36 (TFOpL  (None, 13, 13, 240)  0          ['expanded_conv_5/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_46 (ReLU)                (None, 13, 13, 240)  0           ['tf.__operators__.add_36[0][0]']
#
#  tf.math.multiply_36 (TFOpLambd  (None, 13, 13, 240)  0          ['re_lu_46[0][0]']
#  a)
#
#  multiply_24 (Multiply)         (None, 13, 13, 240)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_36[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_24[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_37 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_47 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_37[0][0]']
#
#  tf.math.multiply_37 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_47[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, 13, 13, 240)  0          ['multiply_24[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_37[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 13, 13, 40)  9600        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 13, 13, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 13, 13, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 13, 13, 120)  4800       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 13, 13, 120)  480        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_38 (TFOpL  (None, 13, 13, 120)  0          ['expanded_conv_6/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_48 (ReLU)                (None, 13, 13, 120)  0           ['tf.__operators__.add_38[0][0]']
#
#  tf.math.multiply_38 (TFOpLambd  (None, 13, 13, 120)  0          ['re_lu_48[0][0]']
#  a)
#
#  multiply_25 (Multiply)         (None, 13, 13, 120)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_38[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, 13, 13, 120)  3000       ['multiply_25[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_6/depthwise/Batc  (None, 13, 13, 120)  480        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_39 (TFOpL  (None, 13, 13, 120)  0          ['expanded_conv_6/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_49 (ReLU)                (None, 13, 13, 120)  0           ['tf.__operators__.add_39[0][0]']
#
#  tf.math.multiply_39 (TFOpLambd  (None, 13, 13, 120)  0          ['re_lu_49[0][0]']
#  a)
#
#  multiply_26 (Multiply)         (None, 13, 13, 120)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_39[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   0           ['multiply_26[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_6/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_6/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_6/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_40 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_6/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_50 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_40[0][0]']
#
#  tf.math.multiply_40 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_50[0][0]']
#  a)
#
#  expanded_conv_6/squeeze_excite  (None, 13, 13, 120)  0          ['multiply_26[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_40[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 13, 13, 48)  5760        ['expanded_conv_6/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_6/project/BatchN  (None, 13, 13, 48)  192         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 13, 13, 144)  6912       ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 13, 13, 144)  576        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_41 (TFOpL  (None, 13, 13, 144)  0          ['expanded_conv_7/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_51 (ReLU)                (None, 13, 13, 144)  0           ['tf.__operators__.add_41[0][0]']
#
#  tf.math.multiply_41 (TFOpLambd  (None, 13, 13, 144)  0          ['re_lu_51[0][0]']
#  a)
#
#  multiply_27 (Multiply)         (None, 13, 13, 144)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_41[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 13, 13, 144)  3600       ['multiply_27[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 13, 13, 144)  576        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_42 (TFOpL  (None, 13, 13, 144)  0          ['expanded_conv_7/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_52 (ReLU)                (None, 13, 13, 144)  0           ['tf.__operators__.add_42[0][0]']
#
#  tf.math.multiply_42 (TFOpLambd  (None, 13, 13, 144)  0          ['re_lu_52[0][0]']
#  a)
#
#  multiply_28 (Multiply)         (None, 13, 13, 144)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_42[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   0           ['multiply_28[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    5800        ['expanded_conv_7/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    0           ['expanded_conv_7/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   5904        ['expanded_conv_7/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_43 (TFOpL  (None, 1, 1, 144)   0           ['expanded_conv_7/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_53 (ReLU)                (None, 1, 1, 144)    0           ['tf.__operators__.add_43[0][0]']
#
#  tf.math.multiply_43 (TFOpLambd  (None, 1, 1, 144)   0           ['re_lu_53[0][0]']
#  a)
#
#  expanded_conv_7/squeeze_excite  (None, 13, 13, 144)  0          ['multiply_28[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_43[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 13, 13, 48)  6912        ['expanded_conv_7/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_7/project/BatchN  (None, 13, 13, 48)  192         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 13, 13, 48)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 13, 13, 288)  13824      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 13, 13, 288)  1152       ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_44 (TFOpL  (None, 13, 13, 288)  0          ['expanded_conv_8/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_54 (ReLU)                (None, 13, 13, 288)  0           ['tf.__operators__.add_44[0][0]']
#
#  tf.math.multiply_44 (TFOpLambd  (None, 13, 13, 288)  0          ['re_lu_54[0][0]']
#  a)
#
#  multiply_29 (Multiply)         (None, 13, 13, 288)  0           ['expanded_conv_8/expand/BatchNor
# ...
#  expanded_conv_9/expand/BatchNo  (None, 7, 7, 576)   2304        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_47 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_57 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_47[0][0]']
#
#  tf.math.multiply_47 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_57[0][0]']
#  a)
#
#  multiply_31 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_47[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 7, 7, 576)   14400       ['multiply_31[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 7, 7, 576)   2304        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_48 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_58 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_48[0][0]']
#
#  tf.math.multiply_48 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_58[0][0]']
#  a)
#
#  multiply_32 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_48[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   0           ['multiply_32[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   83088       ['expanded_conv_9/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   0           ['expanded_conv_9/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   83520       ['expanded_conv_9/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_49 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_9/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_59 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_49[0][0]']
#
#  tf.math.multiply_49 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_59[0][0]']
#  a)
#
#  expanded_conv_9/squeeze_excite  (None, 7, 7, 576)   0           ['multiply_32[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_49[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 7, 7, 96)    55296       ['expanded_conv_9/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_9/project/BatchN  (None, 7, 7, 96)    384         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 7, 7, 96)     0           ['expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 7, 7, 576)   55296       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 7, 7, 576)   2304        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_50 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_60 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_50[0][0]']
#
#  tf.math.multiply_50 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_60[0][0]']
#  a)
#
#  multiply_33 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_50[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 7, 7, 576)   14400       ['multiply_33[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 7, 7, 576)   2304        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_51 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_61 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_51[0][0]']
#
#  tf.math.multiply_51 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_61[0][0]']
#  a)
#
#  multiply_34 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_51[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   0           ['multiply_34[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   83088       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   83520       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_52 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_10/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_62 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_52[0][0]']
#
#  tf.math.multiply_52 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_62[0][0]']
#  a)
#
#  expanded_conv_10/squeeze_excit  (None, 7, 7, 576)   0           ['multiply_34[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_52[0][0]']
#
#  expanded_conv_10/project (Conv  (None, 7, 7, 96)    55296       ['expanded_conv_10/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_10/project/Batch  (None, 7, 7, 96)    384         ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_10/Add (Add)     (None, 7, 7, 96)     0           ['expanded_conv_9/Add[0][0]',
#                                                                   'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 7, 7, 576)    55296       ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 7, 7, 576)   2304        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_53 (TFOpL  (None, 7, 7, 576)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_63 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_53[0][0]']
#
#  tf.math.multiply_53 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_63[0][0]']
#  a)
#
#  multiply_35 (Multiply)         (None, 7, 7, 576)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_53[0][0]']
#
#  flatten_1 (Flatten)            (None, 28224)        0           ['multiply_35[0][0]']
#
#  dense_1 (Dense)                (None, 2)            56450       ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 995,570
# Trainable params: 56,450
# Non-trainable params: 939,120
# __________________________________________________________________________________________________

# %%
# Train the Model

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, test_size=0.2, random_state=5)

print("Splitting data for train and test completed.")
# Out:
# Splitting data for train and test completed.

# %%
# Compiling Model

model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])

print("Model compilation completed.")
# Out:
# Model compilation completed.

# %%
# Fit the Model

history = model.fit(
    xtrain,
    ytrain,
    epochs=epochs,
    batch_size=batch_size,
    verbose=True,
    validation_data=(xtest, ytest)
)

print("Fitting the model completed.")
# Out:
# Epoch 1/10
# 66/66 [==============================] - 13s 119ms/step - loss: 0.3705 - accuracy: 0.9401 - val_loss: 0.3178 - val_accuracy: 0.9492
# Epoch 2/10
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0930 - accuracy: 0.9799 - val_loss: 0.0633 - val_accuracy: 0.9875
# Epoch 3/10
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.0579 - val_accuracy: 0.9847
# Epoch 4/10
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.0637 - val_accuracy: 0.9895
# Epoch 5/10
# 66/66 [==============================] - 4s 57ms/step - loss: 6.7346e-04 - accuracy: 1.0000 - val_loss: 0.0520 - val_accuracy: 0.9895
# Epoch 6/10
# 66/66 [==============================] - 4s 56ms/step - loss: 2.6128e-04 - accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 0.9885
# Epoch 7/10
# 66/66 [==============================] - 4s 57ms/step - loss: 2.2263e-04 - accuracy: 1.0000 - val_loss: 0.0498 - val_accuracy: 0.9895
# Epoch 8/10
# 66/66 [==============================] - 4s 55ms/step - loss: 1.7003e-04 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 0.9904
# Epoch 9/10
# 66/66 [==============================] - 4s 55ms/step - loss: 1.4521e-04 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9904
# Epoch 10/10
# 66/66 [==============================] - 4s 54ms/step - loss: 1.2978e-04 - accuracy: 1.0000 - val_loss: 0.0501 - val_accuracy: 0.9904
# Fitting the model completed.

# %%
# função para plotar gráficos de acurácia e loss do modelo

def plot_model():
    print('Plotando gráficos de acurácia e loss do modelo')
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.gcf().clear()
    plt.figure(figsize=(15, 8))

    plt.subplot(1, 2, 1)
    plt.title('Training and Validation Accuracy')
    plt.plot(epochs_range, accuracy, label='Training Accuracy')
    plt.plot(epochs_range, val_accuracy, label='Validation Accuracy')
    plt.legend(loc='lower right')

    plt.subplot(1, 2, 2)
    plt.title('Training and Validation Loss')
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='lower right')

    plt.show()


plot_model()
# Out:
# Plotando gráficos de acurácia e loss do modelo

# %%
# Preparing prediction arrary
val_predictions = []

for img in val_images:
    img = img.reshape(1, img_width, img_height, 3)
    val_predictions.append(model.predict(img))

test_predictions = []

for img in test_images:
    img = img.reshape(1, img_width, img_height, 3)
    test_predictions.append(model.predict(img))
# Out:
# 1/1 [==============================] - 1s 796ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step

# %%
# This function helps to predict individual image supplied to it
def predict(img_name):
    img = load_img(img_name, target_size=(img_width, img_height))
    img = img_to_array(img)
    plt.imshow(img.astype('int32'))
    plt.show()
    img = preprocess_input(img)

    prediction = model.predict(img.reshape(1, img_width, img_height, 3))
    output = np.argmax(prediction)


# This function plots the image supplied in array
# taking index and 3 arrays viz. prediction array, true label array and image array
def plot_image(i, predictions_array, true_label, img):

    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]

    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img.astype('int32'))

    predicted_label = np.argmax(predictions_array)
    true_label = np.argmax(true_label)

    if predicted_label == true_label:  # setting up label color
        color = 'green'  # correct then blue colour
    else:
        color = 'red'  # wrong then red colour

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label], 100*np.max(
        predictions_array), class_names[true_label]), color=color)


# This function plots bar chart supplied in the array data
# taking index along with predictions and true label array
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    predicted_label = np.argmax(predictions_array)
    true_label = np.argmax(true_label)

    predicted_label = predicted_label + 1
    true_label = true_label + 1

    thisplot = plt.bar(range(2), predicted_label, color='seashell')
    plt.ylim([0, 1])

    thisplot[0].set_label('Normal')
    thisplot[1].set_label('Pneumonia')

    thisplot[predicted_label-1].set_color('red')
    thisplot[true_label-1].set_color('green')


def plot_results(predictions, image_label, images, title='Results'):
    num_rows = 4
    num_cols = 4
    num_images = num_rows*num_cols

    plt.figure(figsize=(2*2*num_cols, 2*num_rows))
    plt.suptitle(title, fontsize=16)

    print("Classification of Test Chest X-ray into Normal and Pneumonia using Transfer Learning (MobileNetV3Small)\n")
    print("Predicted Diagnose, Percentage, (Original Diagnose)\n")

    all_indexes_prediction_list = list(range(len(predictions)))

    def find_indexer():
        indexer = random.choice(all_indexes_prediction_list)
        all_indexes_prediction_list.remove(indexer)
        return indexer

    for i in range(num_images):

        if len(all_indexes_prediction_list) == 0:
            break
        indexer = find_indexer()

        plt.subplot(num_rows, 2*num_cols, 2*i+1)
        plot_image(indexer, predictions, image_label, images)

        plt.subplot(num_rows, 2*num_cols, 2*i+2)
        plot_value_array(indexer, predictions, image_label)

    plt.subplots_adjust(hspace=0.5)
    plt.show()

# %%
# Prediction on Test images
plot_results(
    test_predictions,
    test_image_label,
    test_images_Original, title='Test Results'
)
# Out:
# Classification of Test Chest X-ray into Normal and Pneumonia using Transfer Learning (MobileNetV3Small)
#
# Predicted Diagnose, Percentage, (Original Diagnose)

# %%
# Prediction on Validation images
plot_results(
    val_predictions,
    val_image_label,
    val_images_Original,
    title='Validation Results'
)
# Out:
# Classification of Test Chest X-ray into Normal and Pneumonia using Transfer Learning (MobileNetV3Small)
#
# Predicted Diagnose, Percentage, (Original Diagnose)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns


def plot_confusion_matrix(images, labels, title='Confusion Matrix'):
    Y_pred = model.predict(images)
    # Convert predictions classes to one hot vectors
    Y_pred_classes = np.argmax(Y_pred, axis=1)

    # Convert validation observations to one hot vectors
    Y_true = np.argmax(labels, axis=1)

    # compute the confusion matrix
    confusion_matrix(Y_true, Y_pred_classes)

    f, ax = plt.subplots(figsize=(5, 5))
    sns.heatmap(confusion_matrix(Y_true, Y_pred_classes), annot=True,
                linewidths=0.01, cmap="YlGnBu", linecolor="gray", fmt='.1f', ax=ax)

    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(title)


plot_confusion_matrix(val_images, val_image_label,
                      title='Confusion Matrix on Validation Images')
plot_confusion_matrix(test_images, test_image_label,
                      title='Confusion Matrix on Test Images')
# Out:
# 2/2 [==============================] - 0s 121ms/step
# 20/20 [==============================] - 0s 21ms/step
